# %%
import pandas as pd
import numpy as np
import copy, time
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder

#讀取訓練與測試資料
df_train = pd.read_csv('/Users/max/Downloads/titanic_train.csv')
df_test = pd.read_csv('/Users/max/Downloads/titanic_test.csv')

y_train = df_train['Survived']
ids = df_test['PassengerId']
df_train = df_train.drop(['PassengerId', 'Survived'] , axis=1)
df_test = df_test.drop(['PassengerId'] , axis=1)
df = pd.concat([df_train,df_test])
df.head()
# Out:
#    Pclass                                               Name     Sex   Age  \
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      1      0         A/5 21171   7.2500   NaN        S
# 1      1      0          PC 17599  71.2833   C85        C
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      1      0            113803  53.1000  C123        S
# 4      0      0            373450   8.0500   NaN        S

# %%
#只取類別值 (object) 型欄位, 存於 object_features 中
object_features = []
for dtype, feature in zip(df.dtypes, df.columns):
    if dtype == 'object':
        object_features.append(feature)
print(f'{len(object_features)} Numeric Features : {object_features}\n')

# 只留類別型欄位
df = df[object_features]
df = df.fillna('None')
train_num = y_train.shape[0]
df.head()
# Out:
# 5 Numeric Features : ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']
#                                                 Name     Sex  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171  None        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282  None        S
# 3            113803  C123        S
# 4            373450  None        S

# %% [markdown]
# ## 均值編碼 (Mean Encoding)
#     * 使⽤⽬標值的平均值，取代原本的類別型特徵

# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-03-19%20%E4%B8%8A%E5%8D%8810.54.58.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-03-19%20%E4%B8%8A%E5%8D%8810.54.58.png)

# %%
# 均值編碼 + 邏輯斯迴歸
data = pd.concat([df[:train_num], y_train], axis=1)
for col in object_features:
    print(col)
    df_mean = data.groupby([col])['Survived'].mean().reset_index()
    df_mean.columns = [col, f"{col}_mean"]
    data = pd.merge(data, df_mean, on=col, how='left')
    data = data.drop([col], axis=1)
X_train = data.drop('Survived', axis=1)
clf = LogisticRegression(solver='lbfgs')
clf.fit(X_train, y_train)
print(f"X_train size={X_train.shape}")
print(f"y_train size={y_train.shape}")
print(f"Train score={cross_val_score(clf, X_train, y_train, cv=5, n_jobs=-1).mean():.3f}")
# Out:
# Name
# Sex
# Ticket
# Cabin
# Embarked
# X_train size=(891, 5)
# y_train size=(891,)
# Train score=1.000

# %%
# 對照組 : 標籤編碼 + 邏輯斯迴歸
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

df_temp = pd.DataFrame()
for col in df.columns:
    df_temp[col] = LabelEncoder().fit_transform(df[col])
    
X_train = df_temp[:train_num]
clf = LogisticRegression(solver='lbfgs')
clf.fit(X_train, y_train)
print(f"X_train size={X_train.shape}")
print(f"y_train size={y_train.shape}")
print(f"Train score={cross_val_score(clf, X_train, y_train, cv=5, n_jobs=-1).mean():.3f}")
# Out:
# X_train size=(891, 5)
# y_train size=(891,)
# /Users/max/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# Train score=0.779
