# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv('/Users/max/Downloads/application_train.csv')

# %% [markdown]
# # 正規化

# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-03-04%20%E4%B8%8B%E5%8D%889.45.04.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-03-04%20%E4%B8%8B%E5%8D%889.45.04.png)

# %%
def normalize_value(x):
    """
    Your Code Here, compelete this function
    """
    
    return 2 * (( x - np.min(x) ) / ( np.max(x) - np.min(x) ) - 0.5)

# %%
df['AMT_ANNUITY'].hist(bins = 50)
df['AMT_ANNUITY'].describe()
# Out:
# count    307499.000000
# mean      27108.573909
# std       14493.737315
# min        1615.500000
# 25%       16524.000000
# 50%       24903.000000
# 75%       34596.000000
# max      258025.500000
# Name: AMT_ANNUITY, dtype: float64

# %%
a = normalize_value(df['AMT_ANNUITY'])
a.hist(bins = 50)
a.describe()
# Out:
# count    307499.000000
# mean         -0.801154
# std           0.113051
# min          -1.000000
# 25%          -0.883714
# 50%          -0.818357
# 75%          -0.742752
# max           1.000000
# Name: AMT_ANNUITY, dtype: float64
