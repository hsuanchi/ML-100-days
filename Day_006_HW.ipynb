# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv('/Users/max/Downloads/application_train.csv')

# %%
app_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Columns: 122 entries, SK_ID_CURR to AMT_REQ_CREDIT_BUREAU_YEAR
# dtypes: float64(65), int64(41), object(16)
# memory usage: 286.2+ MB

# %%
dtype_select = ['int64','float64']

# numeric_columns = list(df.columns[list(df.dtypes.isin(dtype_select))])

numeric_columns = list(app_train.columns[list(app_train.dtypes.isin(dtype_select))])

# %%
# 篩選int和float型態
df_select = df.select_dtypes(include=['float64','int64'])

# %%
# 篩選只有兩種型態的數據
for select in df_select:
    if len(np.unique(df_select[select])) ==2:
        del df_select[select]

# %%
# 檢視這些欄位的數值範圍
n_rows = int(np.ceil(df_select.shape[1] / 2))
fig, axes = plt.subplots(n_rows, 2, figsize=(15, n_rows*2))
for (col, ax) in zip(df_select.columns.tolist(), axes.ravel()):
    df_select.boxplot(column=col, ax=ax, vert=False)
    ax.set_yticklabels([])
    ax.set_title(col)
plt.tight_layout()
